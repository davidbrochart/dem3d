# %%
from ipyleaflet import Map, basemaps
from ipywidgets import Output
from dashboard import Dashboard

# %% [markdown]
# # Select a region by clicking the █ on the left and dragging a box with the mouse
# ## It will download some data, show a 2D plot and (after some time) a 3D plot

# %%
m = Map(basemap=basemaps.OpenTopoMap, center=[-15, -60], zoom=4)
m

# %%
notif = Output()
notif

# %% [markdown]
# # 2D plot:

# %%
dem2d = Output()
dem2d

# %% [markdown]
# # 3D (interactive) plot:

# %%
dem3d = Output()
dem3d

# %%
dashboard = Dashboard(m, notif, dem2d, dem3d)
dashboard.start()
